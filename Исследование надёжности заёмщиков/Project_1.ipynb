# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Привет еще раз. Спасибо, что доделала работу. Оформление комментариев по работе сохраняется. Только обозначим, что это вторая итерация.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Привет! Спасибо, что прислала задание:) Поздравляю с первым сданным проектом. Меня зовут Слепцов Артем и я буду проверять твой проект) Ты проделала большую работу над проектом, однако его еще можно улучшить. Будет здорово, если ты, надеюсь, не против, если я буду на ты, будешь отвечать на комментарии и участвовать в диалоге.
#
# (Исполнителем проекта значится Дмиртрий Ерофеев. Советую поработать немного с профилем для того, чтобы небыло различных канфузов. А то был случай, что исполнителем значилась Вера, а первый комментарий в работе был "Привет, я Антон!"😄).
#
# Мои комментарии обозначены пометкой **Комментарий ревьюера**. Далее в файле ты сможешь найти их в похожих ячейках (если фон комментария <font color=green>зелёный</font> - всё сделано правильно. Рекомендации укажу таким же цветом; <font color=orange>оранжевый</font> - некритичные замечания. Если таких замечаний меньше трех - проект может быть принят без их отработки; <font color=red>красный</font> - нужно переделать). Не удаляй эти комментарии и постарайся учесть их в ходе выполнения данного проекта.
#
# <font color=blue> Привет, Артем! Я Наталья. Спасибо за комментарии! Буду стараться учесть их в своей работе.</font>
# </div>

# %% [markdown]
# ## Исследование надёжности заёмщиков
#
# Заказчик — кредитный отдел банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Входные данные от банка — статистика о платёжеспособности клиентов.
#
# Результаты исследования будут учтены при построении модели **кредитного скоринга** — специальной системы, которая оценивает способность потенциального заёмщика вернуть кредит банку.
#
# Описание данных:
# - children — количество детей в семье
# - days_employed — общий трудовой стаж в днях
# - dob_years — возраст клиента в годах
# - education — уровень образования клиента
# - education_id — идентификатор уровня образования
# - family_status — семейное положение
# - family_status_id — идентификатор семейного положения
# - gender — пол клиента
# - income_type — тип занятости
# - debt — имел ли задолженность по возврату кредитов
# - total_income — ежемесячный доход
# - purpose — цель получения кредита

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Вступление в работу очень важно. Так ты поясняешь то, чему она посвящена. Можно также привести краткий план проведения самой работы.
#
# </div>

# %% [markdown]
# ### Шаг 1. Откройте файл с данными и изучите общую информацию.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Я заметил, что ячейки в твоей тетрадке начинаются не с 1. Перед отправкой работы рекомендую перезапускать ноутбук, чтобы убедиться, что все ячейки выполняются корректно.
#
# </div>

# %%
# <импорт библиотеки pandas>
import pandas as pd

# %%
# <чтение файла с данными с сохранением в data_clients>
data_clients = pd.read_csv('/datasets/data.csv')

# <получение первых 10 строк таблицы df>
display(data_clients.head(20))

# <получение общей информации о данных в таблице df>
data_clients.info()
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Таблицы на печать выводи с помощью метода display. print переводит данные в строку, а нам этого не надо.
#
# <font color=blue> Исправила. Спасибо! Не знала о такой функции. </font>
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# 👍
#
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Количество значений в столбцах различается. Это говорит о том, что в данных есть пропущенные значения (days_employed, total_income).
# В данных присутствуют артефакты - отрицательное кол-во дней трудового стажа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# У меня имеется пара комментариев по данному шагу:
# - считывание данных и импорт необходимых библиотек лучше проводить в разных ячейках; <font color=blue> Исправила. </font>
#
# - Подумай также о возможных причинах появления пропусков, а также о том, являются ли они случайными или нет. <font color=blue>
#   Судя по тому, что пропуски есть одновременно в днях трудового стажа и доходе, возможно пропуcки означают реальное отсутствие этих показателей. </font>
#
# Первый взгляд на таблицу выполнен.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Не думаю, т.к. у нас данные о клиентах, уже получивших кредиты. Скорее всего мы имеем техническую ошибку при загрузке данных в таблицу.
#
# </div>

# %% [markdown]
# ### Шаг 2. Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# Проверим, отсутствуют ли данные по столбцам days_employed, total_income в одних и тех же строках.

# %%
data_clients[(data_clients['days_employed'].isnull() == True) & (data_clients['total_income'].isnull() == True)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2174 entries, 12 to 21510
# Data columns (total 12 columns):
# children            2174 non-null int64
# days_employed       0 non-null float64
# dob_years           2174 non-null int64
# education           2174 non-null object
# education_id        2174 non-null int64
# family_status       2174 non-null object
# family_status_id    2174 non-null int64
# gender              2174 non-null object
# income_type         2174 non-null object
# debt                2174 non-null int64
# total_income        0 non-null float64
# purpose             2174 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 220.8+ KB

# %% [markdown]
# В строках, где отсутствуют данные по days_employed, также отсутствуют данные по total_income.
# Проверим, из каких профессий эти люди, чтобы понять, можно ли заполнить пропуски средним по этой группе.

# %%
data_clients[(data_clients['total_income'].isnull() == True) & (data_clients['days_employed'].isnull() == True)]['income_type'].value_counts()
# Out:
# сотрудник          1105
# компаньон           508
# пенсионер           413
# госслужащий         147
# предприниматель       1
# Name: income_type, dtype: int64

# %% [markdown]
# Профессии оказались разные. Соответственно, нужно применять среднее по каждой группе.

# %%
data_clients['total_income'] = data_clients.groupby('income_type')['total_income'].transform(lambda x: x.fillna(x.mean()))
data_clients['days_employed'] = data_clients.groupby('dob_years')['days_employed'].transform(lambda x: x.fillna(x.mean()))
print(data_clients.head(20))
data_clients.info()
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Пропуски в доходе обработаны верно. Конечно, данный параметр сильно зависит от типа занятости клиента. Здорово, что ты использовала такой нетривиальный способ и метод обработки. По стажу все же лучше использовать возраст. Данный параметр наибольшим образом определяет стаж. Однако его мы в анализе не используем, поэтому такая обработка вполне подойдет.
#     <font color = blue> Изменила для стажа группировку на возраст. </font>
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Отлично, данный параметр наилучшим образом подходит для восстановления пропусков. Пусть данный параметр мы и не используем в анализе.
#
# </div>

# %% [markdown]
# ### Замена типа данных

# %%
data_clients['days_employed'] = data_clients['days_employed'].astype('int')

data_clients['total_income'] = data_clients['total_income'].astype('int')
data_clients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
# children            21525 non-null int64
# days_employed       21525 non-null int64
# dob_years           21525 non-null int64
# education           21525 non-null object
# education_id        21525 non-null int64
# family_status       21525 non-null object
# family_status_id    21525 non-null int64
# gender              21525 non-null object
# income_type         21525 non-null object
# debt                21525 non-null int64
# total_income        21525 non-null int64
# purpose             21525 non-null object
# dtypes: int64(7), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
#  Для замены данных на целочисленный использовали метод astype(), так как нам нужен перевод в целое число.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# to_numeric ты освоила, молодец. Однако он переводит числа из текстового формата в численные, а у нас несколько иная ситуация. Нам надо перевести из float в int. В этом тебе поможет метод `as_type`. Попробуй использовать именно его.
#
# </div>
# <font color=blue> Исправила. </font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Верно, теперь тип данныъ изменен у необходимых параметров. Так работа с таблицей будет эффективнее.
#
# </div>

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# Выводим суммарное количество дубликатов.

# %%
print(data_clients.duplicated().sum())
# Out:
# 54

# %% [markdown]
# В файле выявили 54 дубликата. Возможные причины появления дубликатов - человеческий фактор.

# %%
data_clients = data_clients.drop_duplicates()
print(data_clients.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Использовали метод drop_duplicates для удаления дубликатов. Дадее проверили, что дубликатов не осталось.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Дубликаты вызывают смещение финальных результатов, поэтому их и надо удалять. Конечно, в данных нет уникального идентификатора, однако надо уметь удалять дубликаты. Метод drop_duplicates() использован верно.
#
# </div>

# %% [markdown]
# ### Лемматизация

# %% [markdown]
# В датафрейме есть столбец purpose, в нем одни и те же причины выражены разными фразами. Сначала выведем список уникальных целей.

# %%
unique_purposes = data_clients['purpose'].value_counts()
print(unique_purposes)
# Out:
# свадьба                                   793
# на проведение свадьбы                     773
# сыграть свадьбу                           769
# операции с недвижимостью                  675
# покупка коммерческой недвижимости         662
# покупка жилья для сдачи                   652
# операции с жильем                         652
# операции с коммерческой недвижимостью     650
# жилье                                     646
# покупка жилья                             646
# покупка жилья для семьи                   638
# строительство собственной недвижимости    635
# недвижимость                              633
# операции со своей недвижимостью           627
# строительство жилой недвижимости          625
# покупка недвижимости                      621
# покупка своего жилья                      620
# строительство недвижимости                619
# ремонт жилью                              607
# покупка жилой недвижимости                606
# ...

# %% [markdown]
# С помощью модуля pymystem3 произведем лемматизацию целей кредита. Для этого будем использовать метод lemmatize().

# %%
from pymystem3 import Mystem
m = Mystem() 
list_of_lemmas = []
#purpose = data_clients['purpose'].unique()
for row in data_clients['purpose']:
    lemmas = m.lemmatize(row)
    list_of_lemmas.extend(lemmas)
from collections import Counter
display(Counter(list_of_lemmas))
# Out:
# Counter({'покупка': 5900,
#          ' ': 33596,
#          'жилье': 4461,
#          '\n': 21471,
#          'приобретение': 461,
#          'автомобиль': 4308,
#          'дополнительный': 907,
#          'образование': 4014,
#          'сыграть': 769,
#          'свадьба': 2335,
#          'операция': 2604,
#          'с': 2918,
#          'на': 2228,
#          'проведение': 773,
#          'для': 1290,
#          'семья': 638,
#          'недвижимость': 6353,
#          'коммерческий': 1312,
#          'жилой': 1231,
#          'строительство': 1879,
#          'собственный': 635,
#          'подержать': 478,
#          'свой': 2231,
#          'со': 627,
#          'заниматься': 904,
#          'сделка': 941,
#          'подержанный': 486,
#          'получение': 1315,
#          'высокий': 1374,
#          'профильный': 436,
#          'сдача': 652,
#          'ремонт': 607})

# %% [markdown]
# Сформируем список топ-5 целей кредита: недвижимость, автомобиль, образование, свадьба, ремонт

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Круто, ты сделала самую сложную часть проекта. Использовала нужные методы, и даже выделила основные цели получения кредитов.
#
# </div>

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Категоризовать данные по числу детей необязательно. Разбиение есть уже в исходных данных. Все-таки разница в возврате кредита у семей с одним ребенком или двумя детьми будет. Так ты только уменьшаешь объем имеющейся информации.
#
# </div>
#
#    <font color=blue>  Убрала категоризацию по числу детей. </font>

# %% [markdown]
# Создадим отдельный столбец с категорией кол-ва детей (children_num). Для того, чтобы записать в него значения, используем метод apply().

# %% [markdown]
# #### Категоризация по уровню дохода.
# Для определения интервала используем функцию describe().

# %%
data_clients['total_income'].describe()
# Out:
# count    2.147100e+04
# mean     1.674216e+05
# std      9.802416e+04
# min      2.066700e+04
# 25%      1.076545e+05
# 50%      1.518980e+05
# 75%      2.024170e+05
# max      2.265604e+06
# Name: total_income, dtype: float64

# %%
def income_level(row):
    if row <= 107654:
                return 'доход низкий'
    if row <= 151898:
                return 'доход средний'
    if row <= 202417:
                return 'доход выше среднего'
    return 'доход высокий'

# %% [markdown]
# Добавим столбец income_level.

# %%
data_clients['income_level'] = data_clients['total_income'].apply(income_level)
print(data_clients.head(10))
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1          -8437         42    высшее             0
# 1         1          -4024         36   среднее             1
# 2         0          -5623         33   Среднее             1
# 3         3          -4124         32   среднее             1
# 4         0         340266         53   среднее             1
# 5         0           -926         27    высшее             0
# 6         0          -2879         43    высшее             0
# 7         0           -152         50   СРЕДНЕЕ             1
# 8         2          -6929         35    ВЫСШЕЕ             0
# 9         0          -2188         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# ...

# %% [markdown]
# Создадим словарь по семейным статусам.
# Уточним, сколько раз встречаются разные семейные статусы.

# %%
print(data_clients['family_status'].value_counts())
# Out:
# женат / замужем          12344
# гражданский брак          4163
# Не женат / не замужем     2810
# в разводе                 1195
# вдовец / вдова             959
# Name: family_status, dtype: int64

# %% [markdown]
# Создадим новую таблицу data_clients_dict

# %%
data_clients_dict  = data_clients[['family_status', 'family_status_id']]
print(data_clients_dict.head(10))
# Out:
#       family_status  family_status_id
# 0   женат / замужем                 0
# 1   женат / замужем                 0
# 2   женат / замужем                 0
# 3   женат / замужем                 0
# 4  гражданский брак                 1
# 5  гражданский брак                 1
# 6   женат / замужем                 0
# 7   женат / замужем                 0
# 8  гражданский брак                 1
# 9   женат / замужем                 0

# %% [markdown]
# Удалим дубликаты в таблице data_clients_dict.

# %%
data_clients_dict = data_clients_dict.drop_duplicates().reset_index(drop=True)
print(data_clients_dict.sort_values('family_status_id'))
# Out:
#            family_status  family_status_id
# 0        женат / замужем                 0
# 1       гражданский брак                 1
# 2         вдовец / вдова                 2
# 3              в разводе                 3
# 4  Не женат / не замужем                 4

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Для выделения групп по доходам ты использовала квантили данного параметра. Так выделяемые группы у нас получатся равного размера, и мы сможем построить по ним выводы.
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# В данных есть словари. Попробуй их обнаружить и выделить. Это довольно распространенный способ хранения информации. Мне важно понять, что ты его освоила.
#
# </div>
#
# <font color=blue> Выделила словарь по семейным статусам </font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Такой бы выделить и по уровням образования. Затем мы можем убрать текстовые параметры из основной таблицы, что увеличит эффективность работы с ней.
#
# </div>

# %% [markdown]
# ### Шаг 3. Ответьте на вопросы

# %% [markdown]
# - Есть ли зависимость между наличием детей и возвратом кредита в срок?

# %% [markdown]
# Для вывода зависимостей введем функцию relation.

# %%
def relation(category):
    return data_clients.groupby(category)['debt'].mean().to_frame().sort_values('debt')

relation('children')
# Out:
#               debt
# children
#  5        0.000000
# -1        0.021277
#  0        0.075353
#  3        0.081818
#  1        0.092327
#  2        0.094542
#  4        0.097561
#  20       0.105263

# %% [markdown]
# ### Вывод

# %% [markdown]
# В столбце children есть неправдоподобные данные (-1 и 20 детей). Также вызывает вопрос нулевая задолженность у заемщиков с 5 детьми. Если это отбросить, прослеживается рост задолженности с увеличеникм кол-ва детей, но у заемщиков с 3-мя детьми задолженность ниже, чем у заемщиков с 1-м ребенком.
# Заемщики, у которых нет детей, меньше всего подвержены образованию задолженности по кредиту.

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# Посмотри на результаты по полным данным.
#
# </div>
#
# <font color=blue> Сделала по полным данным </font>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера 2</h2>
#
# Нереальные значения стоило обработать. Однако их не так много и на результаты анализа они не повлияют. Но из таблицы все же их стоит удалить.
#
# </div>

# %% [markdown]
# - Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
relation('family_status')
# Out:
#                            debt
# family_status
# вдовец / вдова         0.065693
# в разводе              0.071130
# женат / замужем        0.075421
# гражданский брак       0.093202
# Не женат / не замужем  0.097509

# %% [markdown]
# ### Вывод

# %% [markdown]
# Лица, не связанные юридическими отношениями брака, имеют самый высокий процент задолженности.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера </h2>
#
# Как думаешь, почему мы получаем такой результат? Старайся не просто описывать результат, но и давать ему трактовку.
# </div>
#
# <font color=blue> Возможно потому, что лица, не связанные отношениями брака, имеют более низкий уровень ответственности. </font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Мне кажется, что все же мы имеем скрытую зависимость от возраста клиента. Чем старше, тем более ответственный клиент в среднем. А с возрастом и семейный статус меняется)
#
# </div>

# %% [markdown]
# - Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
relation('income_level')
# Out:
#                          debt
# income_level
# доход высокий        0.070279
# доход низкий         0.079545
# доход выше среднего  0.084807
# доход средний        0.088471

# %% [markdown]
# Выведем эту зависимость в сводную таблицу.

# %%
data_clients.pivot_table(['debt'],['income_level'],aggfunc='mean', fill_value = 0)
# Out:
#                          debt
# income_level
# доход высокий        0.070279
# доход выше среднего  0.084807
# доход низкий         0.079545
# доход средний        0.088471

# %% [markdown]
# ### Вывод

# %% [markdown]
# Заемщики с высоким доходом меньше всего склонны к задолженности по кредиту.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# На данном шаге рекомендуется использовать метод сводных таблиц (pivot_table()). Однако он является аналогом метода groupby(). Изучи метод сводных таблиц и примени его хотя бы в одном пункте анализа.
#
# </div>
#
# <font color=blue> Использовала метод pivot_table для вывода зависимости по доходу. </font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Метод сводных таблиц ты освоила. Он нам сильно пригодится в дальнейших проектах.
#
# </div>

# %% [markdown]
# - Как разные цели кредита влияют на его возврат в срок?

# %%
def purpose(row):
    if 'недвижим' in row:
                return 'недвижимость'
    if 'жиль' in row:
                return 'недвижимость'
    if 'автомоб' in row:
                return 'автомобиль'
    if 'образов' in row:
                return 'образование'
    if 'свад' in row:
                return 'свадьба'
    if 'ремонт' in row:
                return 'ремонт'
    return 'другое'

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Если перед if лемматизировать row, то цели недвижимость, жилье, свадьба и т.д. можно прописывать полностью. В остальном все сделано правильно.
#
# </div>

# %% [markdown]
# Добавим столбец debt_purpose

# %%
data_clients['debt_purpose'] = data_clients['purpose'].apply(purpose)
print(data_clients.head(10))
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1          -8437         42    высшее             0
# 1         1          -4024         36   среднее             1
# 2         0          -5623         33   Среднее             1
# 3         3          -4124         32   среднее             1
# 4         0         340266         53   среднее             1
# 5         0           -926         27    высшее             0
# 6         0          -2879         43    высшее             0
# 7         0           -152         50   СРЕДНЕЕ             1
# 8         2          -6929         35    ВЫСШЕЕ             0
# 9         0          -2188         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt  total_income  \
# 0   женат / замужем                 0      F   сотрудник     0        253875
# 1   женат / замужем                 0      F   сотрудник     0        112080
# ...

# %% [markdown]
# Выведем зависимость между целями кредита и возвратом кредита в срок

# %%
data_clients.pivot_table(['debt'],['debt_purpose'],aggfunc='mean', fill_value = 0)
# Out:
#                   debt
# debt_purpose
# автомобиль    0.093547
# недвижимость  0.072314
# образование   0.092177
# свадьба       0.079657

# %% [markdown]
# Задолженность выше по кредитам, взятым на автомобиль и образование.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Так, основные цели ты выделила. Что нам надо сделать? Надо провести по сути категоризацию по выбранным целям. Как это сделать? Через функцию по аналогии с разбиением по уровням доходов. Мы должны в лемматизированной строке найти одну из выделенных тобой целей и таким образом создать новый параметр с основными целями.
#
# </div>
# <font color=blue> Вывела зависимость </font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Молодец, рад, что у тебя получилось)
#
# </div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# ### Шаг 4. Общий вывод

# %% [markdown]
# Мы провели исследование, которые включают важнейшие стадии предобработки данных (работа с пропусками, удаление дубликатов, замена типа данных, лемматизация и категоризация данных).
# Для этого мы использовала Python и библиотеки pandas, pymystem3.
# Данное исследование позволило ответить на вопросы, есть ли зависимость между различными характеристиками заемщика и своевременной оплаты по кредиту.
# На своевременную выплату по кредиту могут влиять сразу несколько характеристик заемщика: наличие детей, семейное положение, уровень дохода, цель кредита.
# Наиболее ответственные заемщики - у которых нет детей, кто состоит или состоял в зарегистрированных брачных отношениях, у кого высокий доход, а также те, кто берет кредит на недвижимость или свадьбу.

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера </h2>
#
# Финальный вывод и есть главный результат твоей работы. Стоит писать его подробно по результатам проведенной работы. В нем можно приводить полученные в ходе работы значения. Также можно расписать все, что было сделано в работе.
#
# </div>
#
# <font color=blue> Вывод скорректировала </font>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Ответы на главные вопросы проекта приведены. Старайся больший акцент в выводах делать на полученных результатах. Приводи доказательства в виде полученных чисел и значений. Так ты подчеркнешь объем проделанной работы.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера </h2>
#
# - Измени тип данных у параметров с типом float;
# - Выдели словари в данных;
# - Выдели категории по основным целям получения кредитов;
# - Изучи и используй в анализе метод сводных таблиц;
# - Финальный вывод стоит писать подробно.
#
# Ты проделала большую работу, молодец! Исправь отмеченные выше помарки. Также есть достаточное число желтых комментариев. Думаю, исправить их тебе не составит труда. Жду твою работу :)
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера 2</h2>
#
# Помарки исправлены, и теперь работа выполнена хорошо. Ты проделала классную работу, молодец. Успехов в дальнейших проектах :)
#
# </div>

# %% [markdown]
# ### Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл;
# - [x]  файл изучен;
# - [x]  определены пропущенные значения;
# - [x]  заполнены пропущенные значения;
# - [x]  есть пояснение, какие пропущенные значения обнаружены;
# - [x]  описаны возможные причины появления пропусков в данных;
# - [x]  объяснено, по какому принципу заполнены пропуски;
# - [x]  заменен вещественный тип данных на целочисленный;
# - [x]  есть пояснение, какой метод используется для изменения типа данных и почему;
# - [x]  удалены дубликаты;
# - [x]  есть пояснение, какой метод используется для поиска и удаления дубликатов;
# - [x]  описаны возможные причины появления дубликатов в данных;
# - [x]  выделены леммы в значениях столбца с целями получения кредита;
# - [x]  описан процесс лемматизации;
# - [x]  данные категоризированы;
# - [x]  есть объяснение принципа категоризации данных;
# - [x]  есть ответ на вопрос: "Есть ли зависимость между наличием детей и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Есть ли зависимость между семейным положением и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Есть ли зависимость между уровнем дохода и возвратом кредита в срок?";
# - [x]  есть ответ на вопрос: "Как разные цели кредита влияют на его возврат в срок?";
# - [x]  в каждом этапе есть выводы;
# - [x]  есть общий вывод.
